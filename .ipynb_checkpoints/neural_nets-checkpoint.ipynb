# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import pandas as pd
import numpy as np
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def best_output(row):
    # se o downloadTime é diferente de 100 para T2 e T3, ambos os targets completam o download
    if ((row.downloadTimeT2!=100)&(row.downloadTimeT3!=100)):
        # o melhor output será aquele para o qual o downloadTime é menor
        if (row.downloadTimeT2<=row.downloadTimeT3):
            return 0
        else:
            return 1
    
    # se o downloadTime é diferente de 100 apenas para um dos targets, só um deles completa o download
    elif ((row.downloadTimeT2!=100)|(row.downloadTimeT3!=100)):
        # o melhor output será aquele para o qual o downloadTime é diferente de 100
        if (row.downloadTimeT2!=100):
            return 0
        else:
            return 1
        
    # se o downloadTime é igual a 100 para T2 e T3, ambos os targets não completam o download
    elif ((row.downloadTimeT2==100)&(row.downloadTimeT3==100)):
        # o melhor output será aquele para o qual o rxBytes é maior
        if (row.rxBytesT2>=row.rxBytesT3):
            return 0
        else:
            return 1

# %%
def download_complete(row, column):
    if (row[column]==0):
        if(row.downloadTimeT2!=100.0):
            return 1
        else:
            return 0
    else:
        if(row.downloadTimeT3!=100.0):
            return 1
        else: 
            return 0

        
def download_time(row, column):
    if ((row[column]==0)&(row.downloadTimeT2<100)):
        return row.downloadTimeT2
    elif ((row[column]==1)&(row.downloadTimeT3<100)):
        return row.downloadTimeT3

    
def throughput(row, column):
    if (row[column]==0):
        tp = (row.rxBytesT2/row.downloadTimeT2)*8/1e6
        return tp
    else:
        tp = (row.rxBytesT3/row.downloadTimeT3)*8/1e6
        return tp

# %%
def optimum_choice(row, column):
    if (row[column]==row.best_output):
        return 1
    else:
        return 0

# %%
def a2a4rsrp(row):
    if (row.rsrp2>=row.rsrp3):
        return 0
    else:
        return 1

# %% [markdown]
# # Sem Shadowing

# %%
# importando os datasets
t2 = pd.read_csv('resultados/t2_OkumuraHata_Modificado', delimiter='\t')
t3 = pd.read_csv('resultados/t3_OkumuraHata_Modificado', delimiter='\t')

# garantindo que utilizaremos apenas as sementes presentes nos dois datasets
t2 = t2[t2.nRun.isin(t3.nRun)]
t3 = t3[t3.nRun.isin(t2.nRun)]
t2 = t2.reset_index(drop=True)
t3 = t3.reset_index(drop=True)

# %%
# combinando os datasets
data = t2
data = data.drop(['targetCellId', 'downloadTime', 'rxBytes'], axis=1)
data['downloadTimeT2'] = t2.downloadTime
data['downloadTimeT3'] = t3.downloadTime
data['rxBytesT2'] = t2.rxBytes
data['rxBytesT3'] = t3.rxBytes

# %%
data['best_output'] = data.apply(best_output, axis=1)
data.head()
# Out:
#    nRun     angle    rsrp1    rsrq1    rsrp2     rsrq2     rsrp3    rsrq3  \
# 0     1 -54.57300 -91.4534 -4.36266 -96.7808  -9.69006 -102.9210 -15.8302
# 1     2 -24.03920 -91.2610 -4.30386 -97.6844 -10.72730 -100.5270 -13.5702
# 2     3 -20.04290 -91.3627 -4.33647 -97.8093 -10.78300 -100.2320 -13.2054
# 3     4 -49.51330 -91.3211 -4.33040 -96.8836  -9.89290 -102.4740 -15.4829
# 4     5  -9.37145 -91.3008 -4.29974 -98.4062 -11.40520  -99.5329 -12.5319
#
#    previousrsrp1  previousrsrq1  previousrsrp2  previousrsrq2  previousrsrp3  \
# 0       -91.2293       -4.27418       -96.9354        -9.9803      -102.8840
# 1       -91.0186       -4.21518       -97.8386       -11.0352      -100.5620
# 2       -91.1204       -4.24653       -97.9572       -11.0833      -100.2760
# 3       -91.0927       -4.24175       -97.0454       -10.1945      -102.4470
# 4       -91.0547       -4.21276       -98.5311       -11.6892       -99.6079
#
#    previousrsrq3  downloadTimeT2  downloadTimeT3  rxBytesT2  rxBytesT3  \
# 0       -15.9288          37.000        100.0000   15728640   10170752
# 1       -13.7581          46.809        100.0000   15728640   15106984
# 2       -13.4026          48.781         42.7271   15728640   15728640
# 3       -15.5956          38.277        100.0000   15728640   10490760
# 4       -12.7659         100.000         39.6510   15560208   15728640
#
#    best_output
# 0            0
# 1            0
# 2            1
# 3            0
# 4            1

# %%
teste = data[data.nRun>800]
data = data[data.nRun<=800]

# %% [markdown]
# ### Estratégia 1

# %%
# A: Download Completo ou Incompleto (para todas as amostras)
nn1_a_input = data[['rsrp1','rsrq1','rsrp2','rsrq2','rsrp3','rsrq3','previousrsrp1','previousrsrq1','previousrsrp2','previousrsrq2','previousrsrp3','previousrsrq3']]

# NN A para T2
nn1_a0_output = (data.downloadTimeT2<100).astype(int)
nn1_a0 = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(20), random_state=1, validation_fraction=0.25)
nn1_a0.fit(nn1_a_input.as_matrix(), nn1_a0_output);

# NN A para T3
nn1_a1_output = (data.downloadTimeT3<100).astype(int)
nn1_a1 = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(20), random_state=1, validation_fraction=0.25)
nn1_a1.fit(nn1_a_input.as_matrix(), nn1_a1_output);

# %%
print ((nn1_a0.predict(nn1_a_input)==(data.downloadTimeT2!=100).astype(int)).sum()/data.shape[0])
print ((nn1_a1.predict(nn1_a_input)==(data.downloadTimeT3!=100).astype(int)).sum()/data.shape[0])
# Out:
# 0.9975
# 0.99875

# %%
# B: Tempo de Download (para amostras em que ambos os targets completam o download)
nn1_b_input = data[(data.downloadTimeT2!=100)&(data.downloadTimeT3!=100)][['rsrp1','rsrq1','rsrp2','rsrq2','rsrp3','rsrq3','previousrsrp1','previousrsrq1','previousrsrp2','previousrsrq2','previousrsrp3','previousrsrq3']]
# NN B para T2
nn1_b0_output = data[(data.downloadTimeT2!=100)&(data.downloadTimeT3!=100)].downloadTimeT2
nn1_b0 = MLPRegressor(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5), random_state=1, validation_fraction=0.1)
nn1_b0.fit(nn1_b_input.as_matrix(), nn1_b0_output);
# NN B para T3
nn1_b1_output = data[(data.downloadTimeT2!=100)&(data.downloadTimeT3!=100)].downloadTimeT3
nn1_b1 = MLPRegressor(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5), random_state=1, validation_fraction=0.1)
nn1_b1.fit(nn1_b_input.as_matrix(), nn1_b1_output);

# %%
from sklearn.metrics import mean_squared_error
print (mean_squared_error(nn1_b0.predict(nn1_b_input),data[(data.downloadTimeT2!=100)&(data.downloadTimeT3!=100)].downloadTimeT2))
print (mean_squared_error(nn1_b1.predict(nn1_b_input),data[(data.downloadTimeT2!=100)&(data.downloadTimeT3!=100)].downloadTimeT3))
# Out:
# 0.286826277776
# 0.124935778445

# %%
def nn1_func(row):
    nn1_input = row[['rsrp1','rsrq1','rsrp2','rsrq2','rsrp3','rsrq3','previousrsrp1','previousrsrq1','previousrsrp2','previousrsrq2','previousrsrp3','previousrsrq3']].values.reshape(1, -1)
    # Nível 1A
    # se o downloadTime previsto é menor que 100 para T2 e T3, ambos os targets completam o download
    if ((nn1_a0.predict(nn1_input)==1)&(nn1_a1.predict(nn1_input)==1)):
        # Nível 2B
        # o melhor output será aquele para o qual o downloadTime previsto é menor
        if (nn1_b0.predict(nn1_input)<=nn1_b1.predict(nn1_input)):
            return 0
        else:
            return 1
    
    # se o downloadTime previsto é menor que 100 apenas para um dos targets, só um deles completa o download
    elif ((nn1_a0.predict(nn1_input)==1)|(nn1_a1.predict(nn1_input)==1)):
        # o melhor output será aquele para o qual o downloadTime previsto é menor que 100
        if (nn1_a0.predict(nn1_input)==1):
            return 0
        else:
            return 1

# %%
((nn1_a_input.apply(nn1_func, axis=1)==data.best_output).sum())/data.best_output.size
# Out:
# 0.99875000000000003

# %%
import seaborn as sns
features = data[['rsrp1','rsrq1','rsrp2','rsrq2','rsrp3','rsrq3','previousrsrp1','previousrsrq1','previousrsrp2','previousrsrq2','previousrsrp3','previousrsrq3','best_output']]
sns.heatmap(features.corr())

# %% [markdown]
# ### Estratégia 2

# %%
# A: Download Completo ou Incompleto (para todas as amostras)

# NN A para T2
nn2_a0_input = data[['rsrp2','rsrq2']]
nn2_a0_output = (data.downloadTimeT2<100).astype(int)
nn2_a0 = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(20), random_state=1, validation_fraction=0.25)
nn2_a0.fit(nn2_a0_input.as_matrix(), nn2_a0_output);

# NN A para T3
nn2_a1_input = data[['rsrp3','rsrq3']]
nn2_a1_output = (data.downloadTimeT3<100).astype(int)
nn2_a1 = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(20), random_state=1, validation_fraction=0.25)
nn2_a1.fit(nn2_a1_input.as_matrix(), nn2_a1_output);

# %%
print ((nn2_a0.predict(nn2_a0_input)==(data.downloadTimeT2!=100).astype(int)).sum()/data.shape[0])
print ((nn2_a1.predict(nn2_a1_input)==(data.downloadTimeT3!=100).astype(int)).sum()/data.shape[0])
# Out:
# 0.9975
# 0.99875

# %%
# B: Tempo de Download (para amostras em que ambos os targets completam o download)

# NN B para T2
nn2_b0_input = data[(data.downloadTimeT2!=100)&(data.downloadTimeT3!=100)][['rsrp2','rsrq2']]
nn2_b0_output = data[(data.downloadTimeT2!=100)&(data.downloadTimeT3!=100)].downloadTimeT2
nn2_b0 = MLPRegressor(solver='lbfgs', alpha=1e-2, hidden_layer_sizes=(5), random_state=1, validation_fraction=0.1)
nn2_b0.fit(nn2_b0_input.as_matrix(), nn2_b0_output);
# NN B para T3
nn2_b1_input = data[(data.downloadTimeT2!=100)&(data.downloadTimeT3!=100)][['rsrp3','rsrq3']]
nn2_b1_output = data[(data.downloadTimeT2!=100)&(data.downloadTimeT3!=100)].downloadTimeT3
nn2_b1 = MLPRegressor(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5), random_state=1, validation_fraction=0.1)
nn2_b1.fit(nn2_b1_input.as_matrix(), nn2_b1_output);

# %%
from sklearn.metrics import mean_squared_error
print (mean_squared_error(nn2_b0.predict(nn2_b0_input),data[(data.downloadTimeT2!=100)&(data.downloadTimeT3!=100)].downloadTimeT2))
print (mean_squared_error(nn2_b1.predict(nn2_b1_input),data[(data.downloadTimeT2!=100)&(data.downloadTimeT3!=100)].downloadTimeT3))
# Out:
# 1.03581198586
# 0.139856680391

# %%
def nn2_func(row):
    nn2_a0_input = row[['rsrp2','rsrq2']].values.reshape(1, -1)
    nn2_a1_input = row[['rsrp3','rsrq3']].values.reshape(1, -1)
    
    # Nível 1A
    # se ambos os targets completam o download
    if ((nn2_a0.predict(nn2_a0_input)==1)&(nn2_a1.predict(nn2_a1_input)==1)):
        # Nível 2B
        # o melhor output será aquele para o qual o downloadTime previsto é menor
        nn2_b0_input = nn2_a0_input
        nn2_b1_input = nn2_a0_input
        if (nn2_b0.predict(nn2_b0_input)<=nn2_b1.predict(nn2_b1_input)):
            return 0
        else:
            return 1
    
    # se apenas um dos targets completa o download
    elif ((nn2_a0.predict(nn2_a0_input)==1)|(nn2_a1.predict(nn2_a1_input)==1)):
        # o melhor output será aquele que completa o download, segundo a previsão
        if (nn2_a0.predict(nn2_a0_input)==1):
            return 0
        else:
            return 1

# %%
((data.apply(nn2_func, axis=1)==data.best_output).sum())/data.best_output.size
# Out:
# 0.99875000000000003

# %% [markdown]
# ### Estratégia 3

# %%
nn3_input = data[['rsrp2','rsrq2','rsrp3','rsrq3']]
nn3_output = data.best_output

nn3 = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5), random_state=1, validation_fraction=0.25)

nn3.fit(nn3_input.as_matrix(), nn3_output)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=5, learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=1, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.25, verbose=False,
#        warm_start=False)

# %%
def nn3_func(row):
    nn3_input_ = row[['rsrp2','rsrq2','rsrp3','rsrq3']].values.reshape(1, -1)
    return nn3.predict(nn3_input_)[0]

# %%
((data.apply(nn3_func, axis=1)==data.best_output).sum())/data.best_output.size
# Out:
# 0.99875000000000003

# %%
teste['best_choice_download_complete'] = teste.apply(lambda x: download_complete(x, column='best_output'), axis=1)
teste['best_choice_download_time'] = teste.apply(lambda x: download_time(x, column='best_output'), axis=1)
teste['best_choice_throughput'] = teste.apply(lambda x: throughput(x, column='best_output'), axis=1)

# %%
teste['nn1'] = teste.apply(nn1_func, axis=1)
teste['nn1_download_complete'] = teste.apply(lambda x: download_complete(x, column='nn1'), axis=1)
teste['nn1_download_time'] = teste.apply(lambda x: download_time(x, column='nn1'), axis=1)
teste['nn1_throughput'] = teste.apply(lambda x: throughput(x, column='nn1'), axis=1)

# %%
teste['nn2'] = teste.apply(nn2_func, axis=1)
teste['nn2_download_complete'] = teste.apply(lambda x: download_complete(x, column='nn2'), axis=1)
teste['nn2_download_time'] = teste.apply(lambda x: download_time(x, column='nn2'), axis=1)
teste['nn2_throughput'] = teste.apply(lambda x: throughput(x, column='nn2'), axis=1)

# %%
teste['nn3'] = teste.apply(nn3_func, axis=1)
teste['nn3_download_complete'] = teste.apply(lambda x: download_complete(x, column='nn3'), axis=1)
teste['nn3_download_time'] = teste.apply(lambda x: download_time(x, column='nn3'), axis=1)
teste['nn3_throughput'] = teste.apply(lambda x: throughput(x, column='nn3'), axis=1)

# %% [markdown]
# ### Estratégias Clássicas

# %%
teste['a2a4rsrp'] = teste.apply(a2a4rsrp, axis=1)
teste['a2a4rsrp_download_complete'] = teste.apply(lambda x: download_complete(x, column='a2a4rsrp'), axis=1)
teste['a2a4rsrp_download_time'] = teste.apply(lambda x: download_time(x, column='a2a4rsrp'), axis=1)
teste['a2a4rsrp_throughput'] = teste.apply(lambda x: throughput(x, column='a2a4rsrp'), axis=1)

# %%
# importando os datasets com dados de simulações de outras duas estratégias clássicas
a3rsrp = pd.read_csv('resultados/A3RSRP_OkumuraHata_Modificado', delimiter='\t')
a2a4rsrq = pd.read_csv('resultados/A2A4RSRQ_OkumuraHata_Modificado', delimiter='\t')
a3rsrp_teste = a3rsrp[a3rsrp.nRun>800]
a2a4rsrq_teste = a2a4rsrq[a2a4rsrq.nRun>800]

def func(row):
    if (row.downloadTime<100):
        return row.downloadTime
    
teste['a3rsrp_download_complete'] = (a3rsrp_teste.downloadTime<100).astype(int)
teste['a3rsrp_download_time'] = a3rsrp_teste.apply((lambda x: func(x)), axis=1)
teste['a3rsrp_throughput'] = (a3rsrp_teste.rxBytes/a3rsrp_teste.downloadTime)*8/1e6

teste['a2a4rsrq_download_complete'] = (a2a4rsrq_teste.downloadTime<100).astype(int)
teste['a2a4rsrq_download_time'] = a2a4rsrq_teste.apply((lambda x: func(x)), axis=1)
teste['a2a4rsrq_throughput'] = (a2a4rsrq_teste.rxBytes/a2a4rsrq_teste.downloadTime)*8/1e6

# %% [markdown]
# #### Resultados - Sem Shadowing

# %%
estrategias = ['a2a4rsrp', 'a2a4rsrq', 'a3rsrp', 'nn1', 'nn2', 'nn3', 'best_choice']

for estrategia in estrategias:
    print("\n\n", estrategia)
    print("- Geral:")
    print("Percentual de Downloads Completos: ", (teste[estrategia+"_download_complete"].sum()/teste.index.size)*100, "%")
    print("Tempo Médio de Download para os Downloads Completos: ", teste[estrategia+"_download_time"].mean(), "s")
    print("Throughput Médio: ", teste[estrategia+"_throughput"].mean(), "Mbps")
    print("- Para a região central [-30,0]:")
    print("Percentual de Downloads Completos: ", (teste[(teste.angle>-30) & (teste.angle<0)][estrategia+"_download_complete"].sum()/teste[(teste.angle>-30) & (teste.angle<0)].index.size)*100, "%")
    print("Tempo Médio de Download para os Downloads Completos: ", teste[(teste.angle>-30) & (teste.angle<0)][estrategia+"_download_time"].mean(), "s")
    print("Throughput Médio: ", teste[(teste.angle>-30) & (teste.angle<0)][estrategia+"_throughput"].mean(), "Mbps")
# Out:
#  a2a4rsrp
# - Geral:
# Percentual de Downloads Completos:  92.0 %
# Tempo Médio de Download para os Downloads Completos:  41.59430543478259 s
# Throughput Médio:  2.906221099309032 Mbps
# - Para a região central [-30,0]:
# Percentual de Downloads Completos:  73.33333333333333 %
# Tempo Médio de Download para os Downloads Completos:  49.69968181818182 s
# Throughput Médio:  2.161893464161312 Mbps
#
#
#  a2a4rsrq
# - Geral:
# Percentual de Downloads Completos:  94.0 %
# Tempo Médio de Download para os Downloads Completos:  37.64044308510639 s
# Throughput Médio:  3.2636871287363385 Mbps
# - Para a região central [-30,0]:
# Percentual de Downloads Completos:  81.66666666666667 %
# Tempo Médio de Download para os Downloads Completos:  45.55883469387755 s
# Throughput Médio:  2.489373264022782 Mbps
#
#
#  a3rsrp
# - Geral:
# Percentual de Downloads Completos:  99.0 %
# Tempo Médio de Download para os Downloads Completos:  36.659727272727274 s
# Throughput Médio:  3.4881363580313973 Mbps
# - Para a região central [-30,0]:
# Percentual de Downloads Completos:  96.66666666666667 %
# Tempo Médio de Download para os Downloads Completos:  45.12986206896553 s
# Throughput Médio:  2.756103109037523 Mbps
#
#
#  nn1
# - Geral:
# Percentual de Downloads Completos:  100.0 %
# Tempo Médio de Download para os Downloads Completos:  39.92091849999999 s
# Throughput Médio:  3.16038827806331 Mbps
# - Para a região central [-30,0]:
# Percentual de Downloads Completos:  100.0 %
# Tempo Médio de Download para os Downloads Completos:  41.96029166666667 s
# Throughput Médio:  3.0091173933422315 Mbps
#
#
#  nn2
# - Geral:
# Percentual de Downloads Completos:  100.0 %
# Tempo Médio de Download para os Downloads Completos:  39.92091849999999 s
# Throughput Médio:  3.16038827806331 Mbps
# - Para a região central [-30,0]:
# Percentual de Downloads Completos:  100.0 %
# Tempo Médio de Download para os Downloads Completos:  41.96029166666667 s
# Throughput Médio:  3.0091173933422315 Mbps
#
#
#  nn3
# - Geral:
# Percentual de Downloads Completos:  100.0 %
# Tempo Médio de Download para os Downloads Completos:  39.92091849999999 s
# Throughput Médio:  3.16038827806331 Mbps
# - Para a região central [-30,0]:
# Percentual de Downloads Completos:  100.0 %
# Tempo Médio de Download para os Downloads Completos:  41.96029166666667 s
# Throughput Médio:  3.0091173933422315 Mbps
#
#
#  best_choice
# - Geral:
# Percentual de Downloads Completos:  100.0 %
# Tempo Médio de Download para os Downloads Completos:  39.92091849999999 s
# Throughput Médio:  3.16038827806331 Mbps
# - Para a região central [-30,0]:
# Percentual de Downloads Completos:  100.0 %
# Tempo Médio de Download para os Downloads Completos:  41.96029166666667 s
# Throughput Médio:  3.0091173933422315 Mbps

# %% [markdown]
# #### Resultados para o conjunto de teste - OkumuraHata sem shadowing

# %% [markdown]
# #### Geral

# %% [markdown]
# |   |A2A4RSRP|A2A4RSRQ|A3RSRP|NN1|NN2|NN3|BEST CHOICE|
# |---|---|---|---|---|---|---|---|
# |Downloads completos (%)|   |   |   |   |   |   |100.0|
# |Tempo médio de download para os downloads completos (s)|   |   |   |   |   |   |39.92091849999999|
# |Throughput médio (Mbps)|   |   |   |   |   |   |3.16038827806331|

# %% [markdown]
# #### Para a região central [-30,0]

# %% [markdown]
# |   |A2A4RSRP|A2A4RSRQ|A3RSRP|NN1|NN2|NN3|BEST CHOICE|
# |---|---|---|---|---|---|---|---|
# |Downloads completos (%)|   |   |   |   |   |   |100.0|
# |Tempo médio de download para os downloads completos (s)|   |   |   |   |   |   |41.96029166666667|
# |Throughput médio (Mbps)|   |   |   |   |   |   |3.0091173933422315|

# %%
a=1

# %% [markdown]
# a is {{a}}

# %% [markdown]
# # Com Shadowing

# %%
t2 = pd.read_csv('resultados/t2_OhBuildings_ComShadowing', delimiter='\t')
t3 = pd.read_csv('resultados/t3_OhBuildings_ComShadowing', delimiter='\t')
t2 = t2[t2.nRun.isin(t3.nRun)]
t3 = t3[t3.nRun.isin(t2.nRun)]
t2 = t2.reset_index(drop=True)
t3 = t3.reset_index(drop=True)
valid_t2 = t2[t2.rsrp1==t3.rsrp1]
valid_t3 = t3[t2.rsrp1==t3.rsrp1]

# %%
valid = valid_t2
valid = valid.drop(['targetCellId', 'downloadTime', 'rxBytes'], axis=1)
valid['downloadTimeT2'] = valid_t2.downloadTime
valid['downloadTimeT3'] = valid_t3.downloadTime
valid['rxBytesT2'] = valid_t2.rxBytes
valid['rxBytesT3'] = valid_t3.rxBytes
valid['output'] = valid.apply(output, axis=1)
valid = valid.reset_index(drop=True)

# %%
data = valid[0:501]
teste = valid[501:]
teste = teste.reset_index(drop=True)

# %%
data_input = data[['rsrp1','rsrq1','rsrp2','rsrq2','rsrp3','rsrq3','previousrsrp1','previousrsrq1','previousrsrp2','previousrsrq2','previousrsrp3','previousrsrq3']].as_matrix()
data_output = data.output

nn = MLPClassifier(solver='lbfgs', alpha=1e-4,
                   hidden_layer_sizes=(9), random_state=1, validation_fraction=0.3)

nn.fit(data_input,data_output)
(nn.predict(data_input)==data.output).sum()/data.output.size
# Out:
# 0.81836327345309379

# %%
teste_input = teste[['rsrp1','rsrq1','rsrp2','rsrq2','rsrp3','rsrq3','previousrsrp1','previousrsrq1','previousrsrp2','previousrsrq2','previousrsrp3','previousrsrq3']].as_matrix()
teste['nn'] = nn.predict(teste_input)

# %%
teste['a2a4rsrp'] = teste.apply(a2a4rsrp, axis=1)

# %%
teste['a2a4rsrp_optimum_choice'] = teste.apply(lambda x: optimum_choice(x, column='a2a4rsrp'), axis=1)
teste['a2a4rsrp_download_time'] = teste.apply(lambda x: download_time(x, column='a2a4rsrp'), axis=1)
teste['a2a4rsrp_download_complete'] = teste.apply(lambda x: download_complete(x, column='a2a4rsrp'), axis=1)

teste['nn_optimum_choice'] = teste.apply(lambda x: optimum_choice(x, column='nn'), axis=1)
teste['nn_download_time'] = teste.apply(lambda x: download_time(x, column='nn'), axis=1)
teste['nn_download_complete'] = teste.apply(lambda x: download_complete(x, column='nn'), axis=1)

# %% [markdown]
# #### A2A4RSRP

# %%
print("Geral:")
print("Tempo Médio de Download: ", teste.a2a4rsrp_download_time.mean(), "s")
print("Percentual de Downloads Completos: ", (teste.a2a4rsrp_download_complete.sum()/teste.a2a4rsrp_download_complete.size)*100, "%")
print("Percentual de Escolhas Ótimas: ", (teste.a2a4rsrp_optimum_choice.sum()/teste.a2a4rsrp_optimum_choice.size)*100, "%")

print("\nPara a região central [-30,0]:")
print("Tempo Médio de Download: ", teste[(teste.angle>-30) & (teste.angle<0)].a2a4rsrp_download_time.mean(), "s")
print("Percentual de Downloads Completos: ", (teste[(teste.angle>-30) & (teste.angle<0)].a2a4rsrp_download_complete.sum()/teste[(teste.angle>-30) & (teste.angle<0)].a2a4rsrp_download_complete.size)*100, "%")
print("Percentual de Escolhas Ótimas: ", (teste[(teste.angle>-30) & (teste.angle<0)].a2a4rsrp_optimum_choice.sum()/teste[(teste.angle>-30) & (teste.angle<0)].a2a4rsrp_optimum_choice.size)*100, "%")
# Out:
# Geral:
# Tempo Médio de Download:  71.7418652173913 s
# Percentual de Downloads Completos:  45.21739130434783 %
# Percentual de Escolhas Ótimas:  52.17391304347826 %
#
# Para a região central [-30,0]:
# Tempo Médio de Download:  73.16097714285713 s
# Percentual de Downloads Completos:  45.714285714285715 %
# Percentual de Escolhas Ótimas:  40.0 %

# %% [markdown]
# #### Artificial Neural Network

# %%
print("Geral:")
print("Tempo Médio de Download: ", teste.nn_download_time.mean(), "s")
print("Percentual de Downloads Completos: ", (teste.nn_download_complete.sum()/teste.nn_download_complete.size)*100, "%")
print("Percentual de Escolhas Ótimas: ", (teste.nn_optimum_choice.sum()/teste.nn_optimum_choice.size)*100, "%")

print("\nPara a região central [-30,0]:")
print("Tempo Médio de Download: ", teste[(teste.angle>-30) & (teste.angle<0)].nn_download_time.mean(), "s")
print("Percentual de Downloads Completos: ", (teste[(teste.angle>-30) & (teste.angle<0)].nn_download_complete.sum()/teste[(teste.angle>-30) & (teste.angle<0)].nn_download_complete.size)*100, "%")
print("Percentual de Escolhas Ótimas: ", (teste[(teste.angle>-30) & (teste.angle<0)].nn_optimum_choice.sum()/teste[(teste.angle>-30) & (teste.angle<0)].nn_optimum_choice.size)*100, "%")
# Out:
# Geral:
# Tempo Médio de Download:  68.55325826086955 s
# Percentual de Downloads Completos:  48.69565217391305 %
# Percentual de Escolhas Ótimas:  84.34782608695653 %
#
# Para a região central [-30,0]:
# Tempo Médio de Download:  70.09226 s
# Percentual de Downloads Completos:  45.714285714285715 %
# Percentual de Escolhas Ótimas:  77.14285714285715 %

# %%
teste
# Out:
#      nRun     angle     rsrp1     rsrq1     rsrp2     rsrq2     rsrp3  \
# 0     812  11.71950  -91.4992  -3.74510 -104.2300 -16.47550 -100.3510
# 1     813 -29.32410 -122.1520  -6.49248 -126.0650 -10.40490 -135.6450
# 2     814  12.14780 -127.8160 -18.22020 -123.3270 -13.73110 -113.5830
# 3     817 -47.88840  -91.3583  -6.82449  -90.6792  -6.14540  -97.6181
# 4     818 -52.51680 -114.2520  -8.64803 -110.9490  -5.34520 -118.2660
# 5     819 -56.93980  -91.5177  -4.41089 -101.1450 -14.03810  -97.1900
# 6     820 -33.47120  -91.3366  -8.67177  -87.2665  -4.60173 -100.2340
# 7     822 -31.60070  -91.1836 -21.68150  -72.5837  -3.08166  -98.1986
# 8     824  13.48110  -91.4339  -9.80852  -94.0989 -12.47350  -86.3257
# 9     825 -43.91780  -91.2881  -8.03060  -88.1303  -4.87285 -100.9890
# 10    831 -10.09030  -91.3701  -6.41019  -90.8092  -5.84933 -104.4710
# 11    832   5.81576  -91.5108  -6.67964 -103.0680 -18.23720  -90.5178
# 12    833  24.09450  -91.3711  -8.63712  -95.4841 -12.75010  -87.8214
# 13    834   1.32174 -120.4610  -7.59629 -119.8080  -6.94327 -127.7900
# 14    835 -11.19810  -91.4402  -5.13308 -105.1090 -18.80200  -93.7568
# 15    836 -22.01860 -122.0970  -6.94566 -123.7480  -8.59650 -138.6210
# 16    840 -36.44050 -132.1270 -24.76480 -110.7130  -3.35047 -128.0740
# 17    841  15.90800 -118.8530 -16.49280 -106.1190  -3.75807 -115.5040
# 18    842 -48.06940 -106.0500  -6.72145 -110.9010 -11.57200 -106.0330
# 19    843  20.10980 -117.1300  -7.73258 -115.0580  -5.66065 -126.7140
# 20    847 -48.81170  -91.1299  -5.16369  -93.2767  -7.31046 -106.1980
# 21    849 -34.05680 -113.1800  -6.47118 -112.7120  -6.00379 -135.1340
# 22    854 -14.20500  -91.2940 -10.42130  -84.8663  -3.99359 -100.6720
# 23    856  24.43880  -91.5124  -3.59703 -106.9380 -19.02280 -100.8970
# 24    857 -52.39840  -91.2514  -8.89992  -87.0173  -4.66578  -97.6477
# 25    858  19.88280  -91.3252  -3.42042 -105.1260 -17.22070 -103.7910
# 26    859 -48.18130  -91.1238  -5.50866  -92.5981  -6.98288 -103.0160
# 27    860 -56.83220 -123.8230 -20.96480 -106.2100  -3.35250 -119.6940
# 28    861  25.71700  -91.3096  -5.76741 -100.4340 -14.89220  -92.4808
# 29    862 -57.05690  -88.0909  -5.04236  -98.5820 -15.53350  -91.0406
# ..    ...       ...       ...       ...       ...       ...       ...
# 85    947 -19.41590 -108.3250  -4.06686 -114.9720 -10.71430 -124.0470
# 86    951  10.13700  -91.2836  -4.28727 -105.1840 -18.18760  -96.5065
# 87    953  29.78760  -91.4798  -3.83645 -104.4640 -16.82020  -99.4800
# 88    954 -38.16680  -91.3470  -5.32225 -104.1480 -18.12280  -93.2195
# 89    957 -37.84140  -91.4443  -5.48332  -99.5754 -13.61440  -93.5716
# 90    958   4.73706  -91.6752  -5.09129  -96.3684  -9.78450  -97.2905
# 91    959 -18.24950  -95.7692  -3.45293 -111.0460 -18.73010 -106.9740
# 92    963 -33.12520  -91.3913  -6.92177  -92.6621  -8.19258  -92.8538
# 93    965 -23.41210  -86.0289  -3.02512 -177.5590 -94.55540 -110.9400
# 94    968 -36.72190  -91.3655  -4.23175  -98.6511 -11.51730  -99.9907
# 95    970 -15.13040  -93.1206  -4.21315  -98.6595  -9.75200 -107.2480
# 96    972 -19.25420  -91.6308  -9.63761  -89.1496  -7.15637  -89.0110
# 97    973 -21.81760  -89.9664  -3.02735 -162.2640 -75.32470 -114.5710
# 98    974  25.86590 -128.2140 -12.08550 -130.0550 -13.92660 -123.0500
# 99    978   9.10564  -91.2915  -9.77262  -90.8229  -9.30398  -87.0915
# 100   980  -3.99281 -134.0730 -24.29120 -113.9920  -4.21033 -121.2160
# 101   983 -57.80960  -91.2617  -9.71177  -86.1246  -4.57472  -95.0872
# 102   984   8.29421  -91.5207  -3.30533 -106.7420 -18.52710 -105.5510
# 103   986 -46.97300 -112.1040 -11.21760 -107.1420  -6.25640 -108.2890
# 104   987 -39.59420  -91.3616  -8.05891  -90.5997  -7.29707  -91.3387
# 105   988  11.95990  -91.6614  -5.79085  -92.7366  -6.86609 -101.0410
# 106   989 -26.46670  -91.5326 -11.24730  -84.3208  -4.03553  -95.5104
# 107   991 -12.57700  -91.5807  -3.99482 -103.2130 -15.62690  -98.9087
# 108   993  28.61540  -91.5787  -4.75161  -95.1287  -8.30169 -104.5130
# 109   994 -37.93930 -128.1430 -15.15990 -121.2310  -8.24825 -119.4500
# 110   995  15.70410 -127.3590 -18.05830 -115.2190  -5.91841 -116.5580
# 111   996 -33.13770  -91.6602 -13.08410  -85.4099  -6.83374  -84.7116
# 112   998 -10.05460 -109.1080  -9.25868 -118.4030 -18.55430 -104.2520
# 113   999 -20.96470 -114.9340  -8.51234 -111.2080  -4.78624 -128.5300
# 114  1000 -33.38020  -91.5003  -3.82597 -101.3740 -13.69920 -101.3750
#
#         rsrq3  previousrsrp1  previousrsrq1          ...           rxBytesT3  \
# 0   -12.59740       -91.0491       -3.66371          ...            15728640
# 1   -19.98560      -122.1340       -6.48771          ...             1836064
# 2    -3.98637      -127.7870      -18.22620          ...                   0
# 3   -13.08430       -91.1384       -6.62027          ...            13987680
# 4   -12.66200      -114.2310       -8.66301          ...             1836064
# 5   -10.08320       -91.2365       -4.32880          ...             1763664
# 6   -17.56870       -91.1489       -8.39662          ...             7321088
# 7   -28.69660       -91.0584      -21.15390          ...            15728640
# 8    -4.70032       -91.1840       -9.51591          ...            15728640
# 9   -17.73170       -91.1305       -7.76147          ...             9885496
# 10  -19.51120       -91.0363       -6.17217          ...             8808184
# 11   -5.68672       -91.0995       -6.39240          ...            15225720
# 12   -5.08735       -91.1758       -8.38543          ...            15728640
# 13  -14.92500      -120.4910       -7.59798          ...             4378752
# 14   -7.44968       -91.1490       -4.99374          ...             7538288
# 15  -23.46990      -122.0680       -6.93978          ...                   0
# 16  -20.71120      -132.1080      -24.77500          ...                   0
# 17  -13.14320      -118.8240      -16.49780          ...             5241760
# 18   -6.70475      -106.0300       -6.71916          ...            10838280
# 19  -17.31620      -117.1010       -7.73305          ...             9019592
# 20  -20.23150       -91.0072       -5.01849          ...            14199088
# 21  -28.42540      -113.1610       -6.47584          ...            11159736
# 22  -19.79910       -91.1111      -10.15160          ...            15728640
# 23  -12.98110       -91.1077       -3.53547          ...            15728640
# 24  -15.29620       -91.0798       -8.64463          ...             8889272
# 25  -15.88620       -91.0405       -3.38705          ...            15728640
# 26  -17.40090       -91.0031       -5.34730          ...            15728640
# 27  -16.83660      -123.8000      -21.00040          ...                   0
# 28   -6.93858       -91.1393       -5.60664          ...            15728640
# 29   -7.99214       -87.9749       -5.01551          ...            15728640
# ..        ...            ...            ...          ...                 ...
# 85  -19.78910      -108.2960       -4.06808          ...             9036968
# 86   -9.51015       -91.1148       -4.21490          ...            15728640
# 87  -11.83670       -91.1570       -3.76429          ...            15728640
# 88   -7.19483       -91.1077       -5.22057          ...             4622016
# 89   -7.61064       -91.1687       -5.35005          ...            14734848
# 90  -10.70650       -91.2833       -4.91128          ...            10774568
# 91  -14.65740       -95.3315       -3.40530          ...             4190512
# 92   -8.38423       -91.1923       -6.74967          ...            15563104
# 93  -27.93620       -85.9189       -3.02491          ...            15728640
# 94  -12.85690       -91.1230       -4.15149          ...            14236736
# 95  -18.34060       -92.6764       -4.08570          ...            11411688
# 96   -7.01777       -91.2579       -9.27732          ...            14255560
# 97  -27.63160       -89.8565       -3.02710          ...            15728640
# 98   -6.92207      -128.1850      -12.07910          ...                   0
# 99   -5.57264       -91.1423       -9.58383          ...            15728640
# 100 -11.43380      -134.1020      -24.28550          ...                   0
# 101 -13.53730       -91.0879       -9.46642          ...             8910992
# 102 -17.33570       -91.0895       -3.27251          ...            15409616
# 103  -7.40300      -112.0830      -11.22320          ...             9077512
# 104  -8.03600       -91.1538       -7.85451          ...             8129072
# 105 -15.17090       -91.2820       -5.57824          ...            15728640
# 106 -15.22520       -91.2493      -10.89370          ...            11379832
# 107 -11.32280       -91.2477       -3.91279          ...            15728640
# 108 -17.68610       -91.2248       -4.62147          ...            15728640
# 109  -6.46737      -128.1240      -15.15680          ...                   0
# 110  -7.25771      -127.3300      -18.06260          ...                   0
# 111  -6.13547       -91.2913      -12.68290          ...              619744
# 112  -4.40266      -109.0790       -9.26329          ...            12784392
# 113 -22.10790      -114.9050       -8.51855          ...             5438688
# 114 -13.70070       -91.2190       -3.76562          ...            15728640
#
#      output  nn  a2a4rsrp  a2a4rsrp_optimum_choice  a2a4rsrp_download_time  \
# 0         1   1         1                        1                 44.4931
# 1         1   1         0                        0                100.0000
# 2         1   1         1                        1                100.0000
# 3         0   0         0                        1                 36.9890
# 4         1   1         0                        0                100.0000
# 5         0   0         1                        0                100.0000
# 6         0   1         0                        1                 37.8160
# 7         1   1         0                        0                 29.7510
# 8         1   1         1                        1                 39.8760
# 9         0   0         0                        1                 31.0330
# 10        0   1         0                        1                100.0000
# 11        1   1         1                        1                100.0000
# 12        1   1         1                        1                 35.5761
# 13        1   1         0                        0                100.0000
# 14        0   1         1                        0                100.0000
# 15        1   1         0                        0                100.0000
# 16        1   1         0                        0                100.0000
# 17        1   1         0                        0                100.0000
# 18        1   1         1                        1                100.0000
# 19        1   1         0                        0                100.0000
# 20        0   0         0                        1                 25.1771
# 21        1   1         0                        0                100.0000
# 22        1   1         0                        0                 47.3180
# 23        1   1         1                        1                 44.8181
# 24        0   0         0                        1                 32.0781
# 25        1   1         1                        1                 40.7250
# 26        1   0         0                        0                 24.9521
# 27        1   1         0                        0                100.0000
# 28        1   1         1                        1                 33.5551
# 29        1   1         1                        1                 22.3521
# ..      ...  ..       ...                      ...                     ...
# 85        1   1         0                        0                100.0000
# 86        1   1         1                        1                 33.5221
# 87        1   1         1                        1                 42.0651
# 88        0   1         1                        0                100.0000
# 89        0   0         1                        0                100.0000
# 90        1   1         0                        0                100.0000
# 91        0   0         1                        0                100.0000
# 92        1   0         0                        0                100.0000
# 93        1   1         1                        1                 22.3631
# 94        0   0         0                        1                 39.1870
# 95        0   0         0                        1                100.0000
# 96        0   1         1                        0                100.0000
# 97        1   1         1                        1                 22.3701
# 98        1   1         1                        1                100.0000
# 99        1   1         1                        1                 30.8750
# 100       1   1         0                        0                100.0000
# 101       0   0         0                        1                 33.0351
# 102       1   1         1                        1                100.0000
# 103       1   1         0                        0                100.0000
# 104       0   0         0                        1                 36.2390
# 105       1   1         0                        0                100.0000
# 106       0   1         0                        1                 47.2480
# 107       1   1         1                        1                 42.1971
# 108       1   1         0                        0                100.0000
# 109       1   1         1                        1                100.0000
# 110       1   1         0                        0                100.0000
# 111       0   1         1                        0                100.0000
# 112       1   1         1                        1                100.0000
# 113       1   1         0                        0                100.0000
# 114       1   0         0                        0                100.0000
#
#      a2a4rsrp_download_complete  nn_optimum_choice  nn_download_time  \
# 0                             1                  1           44.4931
# 1                             0                  1          100.0000
# 2                             0                  1          100.0000
# 3                             1                  1           36.9890
# 4                             0                  1          100.0000
# 5                             0                  1           44.5721
# 6                             1                  0          100.0000
# 7                             1                  1           26.2660
# 8                             1                  1           39.8760
# 9                             1                  1           31.0330
# 10                            0                  0          100.0000
# 11                            0                  1          100.0000
# 12                            1                  1           35.5761
# 13                            0                  1          100.0000
# 14                            0                  0          100.0000
# 15                            0                  1          100.0000
# 16                            0                  1          100.0000
# 17                            0                  1          100.0000
# 18                            0                  1          100.0000
# 19                            0                  1          100.0000
# 20                            1                  1           25.1771
# 21                            0                  1          100.0000
# 22                            1                  1           36.2920
# 23                            1                  1           44.8181
# 24                            1                  1           32.0781
# 25                            1                  1           40.7250
# 26                            1                  0           24.9521
# 27                            0                  1          100.0000
# 28                            1                  1           33.5551
# 29                            1                  1           22.3521
# ..                          ...                ...               ...
# 85                            0                  1          100.0000
# 86                            1                  1           33.5221
# 87                            1                  1           42.0651
# 88                            0                  0          100.0000
# 89                            0                  1           40.6090
# 90                            0                  1          100.0000
# 91                            0                  1          100.0000
# 92                            0                  0          100.0000
# 93                            1                  1           22.3631
# 94                            1                  1           39.1870
# 95                            0                  1          100.0000
# 96                            0                  0          100.0000
# 97                            1                  1           22.3701
# 98                            0                  1          100.0000
# 99                            1                  1           30.8750
# 100                           0                  1          100.0000
# 101                           1                  1           33.0351
# 102                           0                  1          100.0000
# 103                           0                  1          100.0000
# 104                           1                  1           36.2390
# 105                           0                  1           43.9231
# 106                           1                  0          100.0000
# 107                           1                  1           42.1971
# 108                           0                  1           43.7391
# 109                           0                  1          100.0000
# 110                           0                  1          100.0000
# 111                           0                  0          100.0000
# 112                           0                  1          100.0000
# 113                           0                  1          100.0000
# 114                           0                  0          100.0000
#
#      nn_download_complete
# 0                       1
# 1                       0
# 2                       0
# 3                       1
# 4                       0
# 5                       1
# 6                       0
# 7                       1
# 8                       1
# 9                       1
# 10                      0
# 11                      0
# 12                      1
# 13                      0
# 14                      0
# 15                      0
# 16                      0
# 17                      0
# 18                      0
# 19                      0
# 20                      1
# 21                      0
# 22                      1
# 23                      1
# 24                      1
# 25                      1
# 26                      1
# 27                      0
# 28                      1
# 29                      1
# ..                    ...
# 85                      0
# 86                      1
# 87                      1
# 88                      0
# 89                      1
# 90                      0
# 91                      0
# 92                      0
# 93                      1
# 94                      1
# 95                      0
# 96                      0
# 97                      1
# 98                      0
# 99                      1
# 100                     0
# 101                     1
# 102                     0
# 103                     0
# 104                     1
# 105                     1
# 106                     0
# 107                     1
# 108                     1
# 109                     0
# 110                     0
# 111                     0
# 112                     0
# 113                     0
# 114                     0
#
# [115 rows x 27 columns]
